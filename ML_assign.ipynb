# %%
import numpy as np

# Your data (copy and paste directly from your question)
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])

m = len(x)
alpha = 0.5
theta0 = 0
theta1 = 0
cost_threshold = 0.00000001 # More stringent threshold for better convergence

def h(x_val):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*m)) * np.sum((h(x) - y)**2)
    return cost

previous_cost = float('inf')
iterations = 0
max_iterations = 100000 # Set a maximum number of iterations to prevent infinite loops
while iterations < max_iterations:
    predictions = h(x)
    temp_theta0 = theta0 - alpha * (1/m) * np.sum(predictions - y)
    temp_theta1 = theta1 - alpha * (1/m) * np.sum((predictions - y) * x)
    theta0 = temp_theta0
    theta1 = temp_theta1
    current_cost = cost_function(theta0, theta1, x, y)
    if abs(previous_cost-current_cost)<cost_threshold:
        break
    previous_cost = current_cost
    iterations+=1

print("Theta0 (Intercept):", theta0)
print("Theta1 (Slope):", theta1)
print("Cost:", current_cost)
print("Number of Iterations:", iterations)

x_predict = 9.1
y_predict = h(x_predict)
print(f"Prediction for x = {x_predict}: y = {y_predict}")
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_39180\864843428.py:17: RuntimeWarning: overflow encountered in square
#   cost = (1/(2*m)) * np.sum((h(x) - y)**2)
# c:\Users\KIIT\OneDrive\Attachments\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_39180\864843428.py:30: RuntimeWarning: invalid value encountered in scalar subtract
#   if abs(previous_cost-current_cost)<cost_threshold:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_39180\864843428.py:25: RuntimeWarning: invalid value encountered in scalar subtract
#   temp_theta0 = theta0 - alpha * (1/m) * np.sum(predictions - y)
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_39180\864843428.py:26: RuntimeWarning: invalid value encountered in scalar subtract
#   temp_theta1 = theta1 - alpha * (1/m) * np.sum((predictions - y) * x)
# Theta0 (Intercept): nan
# Theta1 (Slope): nan
# Cost: nan
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
alpha = 0.5
theta0 = 0
theta1 = 0
cost_history = []  # To store cost values
iterations = 0
max_iterations = 50 # Only for first 50 iterations

def h(x_val):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*m)) * np.sum((h(x) - y)**2)
    return cost

for i in range(max_iterations):
    predictions = h(x)
    temp_theta0 = theta0 - alpha * (1/m) * np.sum(predictions - y)
    temp_theta1 = theta1 - alpha * (1/m) * np.sum((predictions - y) * x)
    theta0 = temp_theta0
    theta1 = temp_theta1
    current_cost = cost_function(theta0, theta1, x, y)
    cost_history.append(current_cost)
    iterations += 1

# Plotting
plt.plot(range(1, iterations + 1), cost_history)
plt.xlabel("Iteration")
plt.ylabel("Cost Function")
plt.title("Cost Function vs. Iteration (First 50 Iterations)")
plt.grid(True) # added grid for better readibility
plt.show()

print("Theta0 (Intercept):", theta0)
print("Theta1 (Slope):", theta1)
print("Final Cost:", cost_history[-1]) # printing the final cost after 50 iterations
print("Number of Iterations:", iterations)
# Out:
# Theta0 (Intercept): -2.335405434721258e+74
# Theta1 (Slope): -1.967566622616416e+75
# Final Cost: 1.35288890645998e+152
# Number of Iterations: 50

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
cost_threshold = 0.00000001
max_iterations = 50

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*m)) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

learning_rates = [0.005, 0.5, 5]
plt.figure(figsize=(10, 6))

for lr in learning_rates:
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    iterations = 0

    while iterations < max_iterations:
        predictions = h(x, theta0, theta1)
        temp_theta0 = theta0 - lr * (1/m) * np.sum(predictions - y)
        temp_theta1 = theta1 - lr * (1/m) * np.sum((predictions - y) * x)
        theta0 = temp_theta0
        theta1 = temp_theta1
        current_cost = cost_function(theta0, theta1, x, y)
        cost_history.append(current_cost)
        if abs(previous_cost - current_cost) < cost_threshold:
            break
        previous_cost = current_cost
        iterations += 1
    
    plt.plot(range(1, iterations + 1), cost_history, label=f"lr = {lr}")

plt.xlabel("Iteration")
plt.ylabel("Cost Function (Log Scale)") # More descriptive label
plt.title("Cost Function vs. Iteration for Different Learning Rates (First 50 Iterations)")
plt.legend()
plt.grid(True)
plt.yscale("log")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
cost_threshold = 0.00000001
max_iterations = 50
lr = 0.005 # only one learning rate

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*m)) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

theta0 = 0
theta1 = 0
cost_history = []
previous_cost = float('inf')
iterations = 0

while iterations < max_iterations:
    predictions = h(x, theta0, theta1)
    temp_theta0 = theta0 - lr * (1/m) * np.sum(predictions - y)
    temp_theta1 = theta1 - lr * (1/m) * np.sum((predictions - y) * x)
    theta0 = temp_theta0
    theta1 = temp_theta1
    current_cost = cost_function(theta0, theta1, x, y)
    cost_history.append(current_cost)
    if abs(previous_cost - current_cost) < cost_threshold:
        break
    previous_cost = current_cost
    iterations += 1

# Plotting
plt.plot(range(1, iterations + 1), cost_history, label=f"lr = {lr}")

plt.xlabel("Iteration")
plt.ylabel("Cost Function (Log Scale)")
plt.title(f"Cost Function vs. Iteration for lr = {lr} (First 50 Iterations)") #added lr to the title
plt.legend()
plt.grid(True)
plt.yscale("log")
plt.show()

print("Theta0 (Intercept):", theta0)
print("Theta1 (Slope):", theta1)
print("Final Cost:", cost_history[-1])
print("Number of Iterations:", iterations)
# Out:
# Theta0 (Intercept): 0.024311359538650306
# Theta1 (Slope): 0.1154418025451249
# Final Cost: 0.020386173314650632
# Number of Iterations: 50

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
cost_threshold = 0.00000001
max_iterations = 50
lr = 0.5  # Set learning rate to 0.5

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*m)) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

theta0 = 0
theta1 = 0
cost_history = []
previous_cost = float('inf')
iterations = 0

while iterations < max_iterations:
    predictions = h(x, theta0, theta1)
    temp_theta0 = theta0 - lr * (1/m) * np.sum(predictions - y)
    temp_theta1 = theta1 - lr * (1/m) * np.sum((predictions - y) * x)
    theta0 = temp_theta0
    theta1 = temp_theta1
    current_cost = cost_function(theta0, theta1, x, y)
    cost_history.append(current_cost)
    if abs(previous_cost - current_cost) < cost_threshold:
        break
    previous_cost = current_cost
    iterations += 1

# Plotting
plt.plot(range(1, iterations + 1), cost_history, label=f"lr = {lr}")

plt.xlabel("Iteration")
plt.ylabel("Cost Function (Log Scale)")
plt.title(f"Cost Function vs. Iteration for lr = {lr} (First 50 Iterations)")
plt.legend()
plt.grid(True)
plt.yscale("log")
plt.show()

print("Theta0 (Intercept):", theta0)
print("Theta1 (Slope):", theta1)
print("Final Cost:", cost_history[-1])
print("Number of Iterations:", iterations)
# Out:
# Theta0 (Intercept): -2.335405434721258e+74
# Theta1 (Slope): -1.967566622616416e+75
# Final Cost: 1.35288890645998e+152
# Number of Iterations: 50

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
cost_threshold = 0.00000001
max_iterations = 50
lr = 5  # Set learning rate to 5

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*m)) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

theta0 = 0
theta1 = 0
cost_history = []
previous_cost = float('inf')
iterations = 0

while iterations < max_iterations:
    predictions = h(x, theta0, theta1)
    temp_theta0 = theta0 - lr * (1/m) * np.sum(predictions - y)
    temp_theta1 = theta1 - lr * (1/m) * np.sum((predictions - y) * x)
    theta0 = temp_theta0
    theta1 = temp_theta1
    current_cost = cost_function(theta0, theta1, x, y)
    cost_history.append(current_cost)
    if abs(previous_cost - current_cost) < cost_threshold:
        break
    previous_cost = current_cost
    iterations += 1

# Plotting
plt.plot(range(1, iterations + 1), cost_history, label=f"lr = {lr}")

plt.xlabel("Iteration")
plt.ylabel("Cost Function (Log Scale)")
plt.title(f"Cost Function vs. Iteration for lr = {lr} (First 50 Iterations)")
plt.legend()
plt.grid(True)
plt.yscale("log")
plt.show()

print("Theta0 (Intercept):", theta0)
print("Theta1 (Slope):", theta1)
print("Final Cost:", cost_history[-1])
print("Number of Iterations:", iterations)
# Out:
# Theta0 (Intercept): -8.80454453940721e+124
# Theta1 (Slope): -7.417781814464646e+125
# Final Cost: 1.922876324073027e+253
# Number of Iterations: 50

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data (same as before)
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
lr = 0.5  # Suitable learning rate (from previous tests)
cost_threshold = 0.00000001
max_iterations = 50
batch_size = 10 # for mini batch gradient descent

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*len(x))) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

def batch_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        predictions = h(x, theta0, theta1)
        temp_theta0 = theta0 - lr * (1/len(x)) * np.sum(predictions - y)
        temp_theta1 = theta1 - lr * (1/len(x)) * np.sum((predictions - y) * x)
        theta0 = temp_theta0
        theta1 = temp_theta1
        current_cost = cost_function(theta0, theta1, x, y)
        cost_history.append(current_cost)
        if abs(previous_cost - current_cost) < cost_threshold:
            break
        previous_cost = current_cost
    return theta0, theta1, cost_history

def stochastic_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        for i in range(len(x)):  # Iterate through each data point
            predictions = h(x[i], theta0, theta1)
            temp_theta0 = theta0 - lr * (predictions - y[i])
            temp_theta1 = theta1 - lr * (predictions - y[i]) * x[i]
            theta0 = temp_theta0
            theta1 = temp_theta1
            current_cost = cost_function(theta0, theta1, x, y)
            cost_history.append(current_cost)
            if abs(previous_cost - current_cost) < cost_threshold:
                break
            previous_cost = current_cost
    return theta0, theta1, cost_history
def mini_batch_gradient_descent(x, y, lr, max_iterations, batch_size, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    num_batches

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data (same as before)
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
lr = 0.5  # Suitable learning rate (from previous tests)
cost_threshold = 0.00000001
max_iterations = 50
batch_size = 10 # for mini batch gradient descent

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*len(x))) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

def batch_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        predictions = h(x, theta0, theta1)
        temp_theta0 = theta0 - lr * (1/len(x)) * np.sum(predictions - y)
        temp_theta1 = theta1 - lr * (1/len(x)) * np.sum((predictions - y) * x)
        theta0 = temp_theta0
        theta1 = temp_theta1
        current_cost = cost_function(theta0, theta1, x, y)
        cost_history.append(current_cost)
        if abs(previous_cost - current_cost) < cost_threshold:
            break
        previous_cost = current_cost
    return theta0, theta1, cost_history

def stochastic_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        for i in range(len(x)):  # Iterate through each data point
            predictions = h(x[i], theta0, theta1)
            temp_theta0 = theta0 - lr * (predictions - y[i])
            temp_theta1 = theta1 - lr * (predictions - y[i]) * x[i]
            theta0 = temp_theta0
            theta1 = temp_theta1
            current_cost = cost_function(theta0, theta1, x, y)
            cost_history.append(current_cost)
            if abs(previous_cost - current_cost) < cost_threshold:
                break
            previous_cost = current_cost
    return theta0, theta1, cost_history
def mini_batch_gradient_descent(x, y, lr, max_iterations, batch_size, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    num_batches

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data (same as before)
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
lr = 0.5  # Suitable learning rate (from previous tests)
cost_threshold = 0.00000001
max_iterations = 50
batch_size = 10 # for mini batch gradient descent

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*len(x))) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

def batch_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        predictions = h(x, theta0, theta1)
        temp_theta0 = theta0 - lr * (1/len(x)) * np.sum(predictions - y)
        temp_theta1 = theta1 - lr * (1/len(x)) * np.sum((predictions - y) * x)
        theta0 = temp_theta0
        theta1 = temp_theta1
        current_cost = cost_function(theta0, theta1, x, y)
        cost_history.append(current_cost)
        if abs(previous_cost - current_cost) < cost_threshold:
            break
        previous_cost = current_cost
    return theta0, theta1, cost_history

def stochastic_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        for i in range(len(x)):  # Iterate through each data point
            predictions = h(x[i], theta0, theta1)
            temp_theta0 = theta0 - lr * (predictions - y[i])
            temp_theta1 = theta1 - lr * (predictions - y[i]) * x[i]
            theta0 = temp_theta0
            theta1 = temp_theta1
            current_cost = cost_function(theta0, theta1, x, y)
            cost_history.append(current_cost)
            if abs(previous_cost - current_cost) < cost_threshold:
                break
            previous_cost = current_cost
    return theta0, theta1, cost_history
def mini_batch_gradient_descent(x, y, lr, max_iterations, batch_size, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    num_batches

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def load_data():
    independent_path = 'data/linearX.csv'
    dependent_path = 'data/linearY.csv'

    X = pd.read_csv(independent_path, header=None).values
    Y = pd.read_csv(dependent_path, header=None).values
    Y = Y.reshape(-1, 1)
    return X, Y

def normalize_data(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    X_norm = (X - mean) / std
    return X_norm

def add_intercept(X):
    return np.c_[np.ones(X.shape[0]), X]

def compute_cost(X, Y, theta):
    m = len(Y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum((predictions - Y) ** 2)
    return cost

def gradient_descent(X, Y, theta, alpha, num_iters):
    m = len(Y)
    cost_history = []

    for i in range(num_iters):
        prediction = X.dot(theta)
        error = prediction - Y
        theta -= (alpha / m) * X.T.dot(error)

        cost = compute_cost(X, Y, theta)
        cost_history.append(cost)

        if i > 0 and abs(cost_history[i] - cost_history[i - 1]) < 1e-6:
            break

    return theta, cost_history

X, Y = load_data()
X = normalize_data(X)
X = add_intercept(X)

theta_initial = np.zeros((X.shape[1], 1))
alpha = 0.5
num_iters = 1000

theta_optimal, cost_history = gradient_descent(X, Y, theta_initial, alpha, num_iters)

# Plot the first figure (Cost Function vs Iterations)
plt.plot(cost_history[:50])
plt.xlabel('Iteration')
plt.ylabel('Cost')
plt.title('Cost Function vs Iterations')
plt.show()

# Plot the second figure (Data + Fitted Line)
plt.scatter(X[:, 1], Y, color='blue', label='Data')
plt.plot(X[:, 1], X.dot(theta_optimal), color='red', label='Fitted line')
plt.xlabel('Predictor')
plt.ylabel('Response')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()

# Trying three different learning rates and plotting each result separately
learning_rates = [0.005, 0.5, 5]

# Create subplots for each learning rate (Cost Function vs Iterations)
fig, axs = plt.subplots(3, 1, figsize=(10, 18))

for i, lr in enumerate(learning_rates):
    # Run gradient descent for the current learning rate
    theta_optimal_lr, cost_history_lr = gradient_descent(X, Y, theta_initial, lr, num_iters=1000)

    # Plot cost history for each learning rate on the respective subplot
    axs[i].plot(cost_history_lr[:50])  # Plot only the first 50 iterations
    axs[i].set_title(f'Cost Function for lr={lr}')
    axs[i].set_xlabel('Iteration')
    axs[i].set_ylabel('Cost')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# Optional: Print optimal parameters for the learning rates (You can include them in the report)
for lr in learning_rates:
    theta_optimal_lr, cost_history_lr = gradient_descent(X, Y, theta_initial, lr, num_iters=1000)
    print(f"Optimal parameters for lr={lr}:")
    print(f"θ₀ = {theta_optimal_lr[0]}")
    print(f"θ₁ = {theta_optimal_lr[1]}")
    print(f"Final cost function value: {cost_history_lr[-1]}\n")


def batch_gradient_descent(X, Y, theta, alpha, num_iters):
    m = len(Y)
    cost_history = []

    for i in range(num_iters):
        prediction = X.dot(theta)
        error = prediction - Y
        theta -= (alpha / m) * X.T.dot(error)

        cost = compute_cost(X, Y, theta)
        cost_history.append(cost)

        if i > 0 and abs(cost_history[i] - cost_history[i - 1]) < 1e-6:
            break

    return theta, cost_history


def stochastic_gradient_descent(X, Y, theta, alpha, num_iters):
    m = len(Y)
    cost_history = []

    for i in range(num_iters):
        for j in range(m):
            rand_index = np.random.randint(m)
            X_rand = X[rand_index:rand_index + 1]
            Y_rand = Y[rand_index:rand_index + 1]
            prediction = X_rand.dot(theta)
            error = prediction - Y_rand
            theta -= alpha * X_rand.T.dot(error)

        cost = compute_cost(X, Y, theta)
        cost_history.append(cost)

        if i > 0 and abs(cost_history[i] - cost_history[i - 1]) < 1e-6:
            break

    return theta, cost_history


def mini_batch_gradient_descent(X, Y, theta, alpha, num_iters, batch_size=32):
    m = len(Y)
    cost_history = []
    for i in range(num_iters):
        # Shuffle the data for each iteration
        shuffle_index = np.random.permutation(m)
        X_shuffled = X[shuffle_index]
        Y_shuffled = Y[shuffle_index]

        for j in range(0, m, batch_size):
            X_batch = X_shuffled[j:j + batch_size]
            Y_batch = Y_shuffled[j:j + batch_size]

            prediction = X_batch.dot(theta)
            error = prediction - Y_batch
            theta -= (alpha / batch_size) * X_batch.T.dot(error)

        cost = compute_cost(X, Y, theta)
        cost_history.append(cost)

        if i > 0 and abs(cost_history[i] - cost_history[i - 1]) < 1e-6:
            break

    return theta, cost_history


# Load and preprocess data
X, Y = load_data()
X = normalize_data(X)
X = add_intercept(X)

theta_initial = np.zeros((X.shape[1], 1))
alpha = 0.5
num_iters = 1000

# Run Batch Gradient Descent
theta_optimal_batch, cost_history_batch = batch_gradient_descent(X, Y, theta_initial, alpha, num_iters)

# Run Stochastic Gradient Descent
theta_optimal_sgd, cost_history_sgd = stochastic_gradient_descent(X, Y, theta_initial, alpha, num_iters)

# Run Mini-Batch Gradient Descent
theta_optimal_mini_batch, cost_history_mini_batch = mini_batch_gradient_descent(X, Y, theta_initial, alpha, num_iters,
                                                                                batch_size=32)

# Plot the cost function for each method independently
fig, axs = plt.subplots(3, 1, figsize=(10, 18))

# Batch Gradient Descent Cost
axs[0].plot(cost_history_batch[:50])  # Plot first 50 iterations
axs[0].set_title('Cost Function for Batch Gradient Descent')
axs[0].set_xlabel('Iteration')
axs[0].set_ylabel('Cost')

# Stochastic Gradient Descent Cost
axs[1].plot(cost_history_sgd[:50])  # Plot first 50 iterations
axs[1].set_title('Cost Function for Stochastic Gradient Descent')
axs[1].set_xlabel('Iteration')
axs[1].set_ylabel('Cost')

# Mini-Batch Gradient Descent Cost
axs[2].plot(cost_history_mini_batch[:50])  # Plot first 50 iterations
axs[2].set_title('Cost Function for Mini-Batch Gradient Descent')
axs[2].set_xlabel('Iteration')
axs[2].set_ylabel('Cost')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# Print optimal parameters and final cost function values for each method
print("Batch Gradient Descent:")
print(f"Optimal parameters θ₀ = {theta_optimal_batch[0]}, θ₁ = {theta_optimal_batch[1]}")
print(f"Final cost: {cost_history_batch[-1]}\n")

print("Stochastic Gradient Descent:")
print(f"Optimal parameters θ₀ = {theta_optimal_sgd[0]}, θ₁ = {theta_optimal_sgd[1]}")
print(f"Final cost: {cost_history_sgd[-1]}\n")

print("Mini-Batch Gradient Descent:")
print(f"Optimal parameters θ₀ = {theta_optimal_mini_batch[0]}, θ₁ = {theta_optimal_mini_batch[1]}")
print(f"Final cost: {cost_history_mini_batch[-1]}\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 46
#      42             break
#      44     return theta, cost_history
# ---> 46 X, Y = load_data()
#      47 X = normalize_data(X)
#      48 X = add_intercept(X)
#
# Cell In[13], line 9, in load_data()
#       6 independent_path = 'data/linearX.csv'
#       7 dependent_path = 'data/linearY.csv'
# ----> 9 X = pd.read_csv(independent_path, header=None).values
#      10 Y = pd.read_csv(dependent_path, header=None).values
#      11 Y = Y.reshape(-1, 1)
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
lr = 0.5  # Suitable learning rate (from previous tests)
cost_threshold = 0.00000001
max_iterations = 50
batch_size = 10

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*len(x))) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

def batch_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        predictions = h(x, theta0, theta1)
        temp_theta0 = theta0 - lr * (1/len(x)) * np.sum(predictions - y)
        temp_theta1 = theta1 - lr * (1/len(x)) * np.sum((predictions - y) * x)
        theta0 = temp_theta0
        theta1 = temp_theta1
        current_cost = cost_function(theta0, theta1, x, y)
        cost_history.append(current_cost)
        if abs(previous_cost - current_cost) < cost_threshold:
            break
        previous_cost = current_cost
    return theta0, theta1, cost_history

def stochastic_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        for i in range(len(x)):  # Iterate through each data point
            predictions = h(x[i], theta0, theta1)
            temp_theta0 = theta0 - lr * (predictions - y[i])
            temp_theta1 = theta1 - lr * (predictions - y[i]) * x[i]
            theta0 = temp_theta0
            theta1 = temp_theta1
            current_cost = cost_function(theta0, theta1, x, y)
            cost_history.append(current_cost)
            if abs(previous_cost - current_cost) < cost_threshold:
                break
            previous_cost = current_cost
    return theta0, theta1, cost_history

def mini_batch_gradient_descent(x, y, lr, max_iterations, batch_size, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    num_batches = int(np.ceil(len(x)
# Out:
#   Cell In[14], line 62
#     num_batches = int(np.ceil(len(x)
#                                     ^
# SyntaxError: incomplete input

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your data
x = np.array([9.1, 8, 9.1, 8.4, 6.9, 7.7, 15.6, 7.3, 7, 7.2, 10.1, 11.5, 7.1, 10, 8.9, 7.9, 5.6, 6.3, 6.7, 10.4, 8.5, 7.4, 6.3, 5.4, 8.9, 9.4, 7.5, 11.9, 7.8, 7.4, 10.8, 10.2, 6.2, 7.7, 13.7, 8, 6.7, 6.7, 7, 8.3, 7.4, 9.9, 6.1, 7, 5.4, 10.7, 7.6, 8.9, 9.2, 6.6, 7.2, 8, 7.8, 7.9, 7, 7, 7.6, 9.1, 9, 7.9, 6.6, 11.9, 6.5, 7.1, 8.8, 7.5, 7.7, 6, 10.6, 6.6, 8.2, 7.9, 7.1, 5.6, 6.4, 7.5, 9.8, 7, 10.5, 7.1, 6.2, 6.5, 7.7, 7.2, 9.3, 8.5, 7.7, 6.8, 7.8, 8.7, 9.6, 7.2, 9.3, 8.1, 6.6, 7.8, 10.2, 6.1, 7.3, 7.3])
y = np.array([0.99523, 0.99007, 0.99769, 0.99386, 0.99508, 0.9963, 1.0032, 0.99768, 0.99584, 0.99609, 0.99774, 1.0003, 0.99694, 0.99965, 0.99549, 0.99364, 0.99378, 0.99379, 0.99524, 0.9988, 0.99733, 0.9966, 0.9955, 0.99471, 0.99354, 0.99786, 0.9965, 0.9988, 0.9964, 0.99713, 0.9985, 0.99565, 0.99578, 0.9976, 1.0014, 0.99685, 0.99648, 0.99472, 0.99914, 0.99408, 0.9974, 1.0002, 0.99402, 0.9966, 0.99402, 1.0029, 0.99718, 0.9986, 0.9952, 0.9952, 0.9972, 0.9976, 0.9968, 0.9978, 0.9951, 0.99629, 0.99656, 0.999, 0.99836, 0.99396, 0.99387, 1.0004, 0.9972, 0.9972, 0.99546, 0.9978, 0.99596, 0.99572, 0.9992, 0.99544, 0.99747, 0.99668, 0.9962, 0.99346, 0.99514, 0.99476, 1.001, 0.9961, 0.99598, 0.99608, 0.9966, 0.99732, 0.9962, 0.99546, 0.99738, 0.99456, 0.9966, 0.99553, 0.9984, 0.9952, 0.997, 0.99586, 0.9984, 0.99542, 0.99655, 0.9962, 0.9976, 0.99464, 0.9983, 0.9967])
m = len(x)
lr = 0.5  # Suitable learning rate
cost_threshold = 0.00000001
max_iterations = 50
batch_size = 10

def h(x_val, theta0, theta1):
    return theta0 + theta1 * x_val

def cost_function(theta0, theta1, x, y):
    cost = (1/(2*len(x))) * np.sum((h(x, theta0, theta1) - y)**2)
    return cost

def batch_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        predictions = h(x, theta0, theta1)
        temp_theta0 = theta0 - lr * (1/len(x)) * np.sum(predictions - y)
        temp_theta1 = theta1 - lr * (1/len(x)) * np.sum((predictions - y) * x)
        theta0 = temp_theta0
        theta1 = temp_theta1
        current_cost = cost_function(theta0, theta1, x, y)
        cost_history.append(current_cost)
        if abs(previous_cost - current_cost) < cost_threshold:
            break
        previous_cost = current_cost
    return theta0, theta1, cost_history

def stochastic_gradient_descent(x, y, lr, max_iterations, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    for _ in range(max_iterations):
        for i in range(len(x)):  # Iterate through each data point
            predictions = h(x[i], theta0, theta1)
            temp_theta0 = theta0 - lr * (predictions - y[i])
            temp_theta1 = theta1 - lr * (predictions - y[i]) * x[i]
            theta0 = temp_theta0
            theta1 = temp_theta1
            current_cost = cost_function(theta0, theta1, x, y)
            cost_history.append(current_cost)
            if abs(previous_cost - current_cost) < cost_threshold:
                break
            previous_cost = current_cost
    return theta0, theta1, cost_history

def mini_batch_gradient_descent(x, y, lr, max_iterations, batch_size, cost_threshold):
    theta0 = 0
    theta1 = 0
    cost_history = []
    previous_cost = float('inf')
    num_batches = int(np.ceil(len(x) / batch_size))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)
m = 100  # Number of data points
X = 2 * np.random.rand(m, 1)  # Features
y = 4 + 3 * X + np.random.randn(m, 1)  # Labels with some noise

# Add bias term to X
X_b = np.c_[np.ones((m, 1)), X]

# Define hyperparameters
learning_rate = 0.1
n_iterations = 1000
mini_batch_size = 20

# Cost function
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return cost

# Batch Gradient Descent
def batch_gradient_descent(X, y, learning_rate, n_iterations):
    m, n = X.shape
    theta = np.random.randn(n, 1)  # Initialize parameters
    cost_history = []

    for iteration in range(n_iterations):
        gradients = (1 / m) * X.T.dot(X.dot(theta) - y)
        theta -= learning_rate * gradients
        cost_history.append(compute_cost(X, y, theta))

    return theta, cost_history

# Stochastic Gradient Descent
def stochastic_gradient_descent(X, y, learning_rate, n_iterations):
    m, n = X.shape
    theta = np.random.randn(n, 1)  # Initialize parameters
    cost_history = []

    for iteration in range(n_iterations):
        for i in range(m):
            random_index = np.random.randint(m)
            xi = X[random_index:random_index + 1]
            yi = y[random_index:random_index + 1]
            gradients = 2 * xi.T.dot(xi.dot(theta) - yi)
            theta -= learning_rate * gradients
        cost_history.append(compute_cost(X, y, theta))

    return theta, cost_history

# Mini-Batch Gradient Descent
def mini_batch_gradient_descent(X, y, learning_rate, n_iterations, batch_size):
    m, n = X.shape
    theta = np.random.randn(n, 1)  # Initialize parameters
    cost_history = []

    for iteration in range(n_iterations):
        shuffled_indices = np.random.permutation(m)
        X_shuffled = X[shuffled_indices]
        y_shuffled = y[shuffled_indices]

        for i in range(0, m, batch_size):
            xi = X_shuffled[i:i + batch_size]
            yi = y_shuffled[i:i + batch_size]
            gradients = (2 / batch_size) * xi.T.dot(xi.dot(theta) - yi)
            theta -= learning_rate * gradients
        cost_history.append(compute_cost(X, y, theta))

    return theta, cost_history

# Run gradient descent variants
batch_theta, batch_cost_history = batch_gradient_descent(X_b, y, learning_rate, n_iterations)
stochastic_theta, stochastic_cost_history = stochastic_gradient_descent(X_b, y, learning_rate, n_iterations)
mini_batch_theta, mini_batch_cost_history = mini_batch_gradient_descent(X_b, y, learning_rate, n_iterations, mini_batch_size)

# Plot cost function vs iterations
plt.figure(figsize=(10, 6))
plt.plot(batch_cost_history, label="Batch Gradient Descent")
plt.plot(stochastic_cost_history, label="Stochastic Gradient Descent")
plt.plot(mini_batch_cost_history, label="Mini-Batch Gradient Descent")
plt.title("Cost Function vs Iterations")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.legend()
plt.grid()
plt.show()
